# %%
#Datos sinteticos
#Juan Gerardo
#5 de junio del 2026

# %%
import pandas as pd
import numpy as np
import random

# %%
from faker import Faker

# %%
fake = Faker("es_MX")

# %%
datos = []
for i in range(100):
    datos.append(
        {
            "id_usuario": i +1,
            "nombre" : fake.name(),
            "correo" : fake.email(),
            "edad" : random.randint(18,65),
            "seguidores" : random.randint(50,5000),
            "plataforma" : random.choice(["TikTok", "Instagram", "YouTube"])
        }
    )

# %%
dfInfluencer = pd.DataFrame(datos)

# %%
dfInfluencer
# Out:
#     id_usuario                      nombre                       correo  edad  \
# 0            1      Rolando Gregorio Jasso         efajardo@example.org    37
# 1            2      José Luis Jasso Guerra    carrionrufino@example.net    21
# 2            3    Ing. Luis Miguel Casárez          ycortes@example.net    62
# 3            4        Pablo Heredia Lomeli  montenegrojuana@example.net    31
# 4            5            Alfonso Reséndez            jmeza@example.com    43
# ..         ...                         ...                          ...   ...
# 95          96  Marco Antonio Mauro Tejeda        pascual85@example.com    42
# 96          97      Nelly Yuridia Quiñones           lavila@example.net    56
# 97          98           Ana Cecilia Nieto         sluevano@example.com    38
# 98          99      Ivonne Esparta Venegas     jose-maria61@example.org    47
# 99         100    Lic. Benjamín Montemayor         ofelia86@example.net    38
#
#     seguidores plataforma
# 0          904     TikTok
# 1         4522  Instagram
# 2         1587    YouTube
# 3         2756  Instagram
# 4          401     TikTok
# ..         ...        ...
# 95        4571    YouTube
# 96        1628     TikTok
# 97        1562     TikTok
# 98         620    YouTube
# 99        1146     TikTok
#
# [100 rows x 6 columns]

# %%
dfInfluencer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_usuario  100 non-null    int64
#  1   nombre      100 non-null    object
#  2   correo      100 non-null    object
#  3   edad        100 non-null    int64
#  4   seguidores  100 non-null    int64
#  5   plataforma  100 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 4.8+ KB

# %%
dfInfluencer.describe()
# Out:
#        id_usuario        edad  seguidores
# count  100.000000  100.000000   100.00000
# mean    50.500000   41.890000  2524.72000
# std     29.011492   13.970311  1522.87624
# min      1.000000   18.000000   213.00000
# 25%     25.750000   29.000000  1043.50000
# 50%     50.500000   43.000000  2688.50000
# 75%     75.250000   53.000000  3985.00000
# max    100.000000   65.000000  4919.00000

# %%
dfInfluencer.describe(include="all")
# Out:
#         id_usuario                  nombre                correo        edad  \
# count   100.000000                     100                   100  100.000000
# unique         NaN                     100                   100         NaN
# top            NaN  Rolando Gregorio Jasso  efajardo@example.org         NaN
# freq           NaN                       1                     1         NaN
# mean     50.500000                     NaN                   NaN   41.890000
# std      29.011492                     NaN                   NaN   13.970311
# min       1.000000                     NaN                   NaN   18.000000
# 25%      25.750000                     NaN                   NaN   29.000000
# 50%      50.500000                     NaN                   NaN   43.000000
# 75%      75.250000                     NaN                   NaN   53.000000
# max     100.000000                     NaN                   NaN   65.000000
#
#         seguidores plataforma
# count    100.00000        100
# unique         NaN          3
# top            NaN    YouTube
# freq           NaN         38
# mean    2524.72000        NaN
# std     1522.87624        NaN
# min      213.00000        NaN
# 25%     1043.50000        NaN
# 50%     2688.50000        NaN
# 75%     3985.00000        NaN
# max     4919.00000        NaN

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (8,4))
sns.histplot(dfInfluencer["edad"], bins=10)
plt.title("Distribución de edades")
plt.show()

# %%
#Graficamos la cantidad de usuarios en la plataforma
plt.figure(figsize =(8,4))
sns.countplot(x="plataforma", data = dfInfluencer)
plt.title("cantidad de usuarios por plataforma")
plt.show()
